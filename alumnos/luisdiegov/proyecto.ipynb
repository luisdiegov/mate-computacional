# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import random
import copy
import pdb
from collections import *

Coord = namedtuple('Coord', 'r c')
Move = namedtuple('Move', 'pos player')

def flatten(x):
    return [inner for outer in x for inner in outer]

class Board():
    def __init__(self):
        self.b = [['' for x in range(3)] for x in range(3)]

    def winner(self):
        # yes, this is lazy.
        for p in ['X', 'O']:
            for r in range(3):
                if all(x == p for x in self.b[r]):
                    return p

            for c in range(3):
                if all(r[c] == p for r in self.b):
                    return p

            if self.b[0][0] == p and self.b[1][1] == p and self.b[2][2] == p:
                return p

            if self.b[0][2] == p and self.b[1][1] == p and self.b[2][0] == p:
                return p

        return 'T' if self.full() else ''

    def full(self):
        return not any(x == '' for x in flatten(self.b))

    def count(self):
        return sum(int(x != '') for x in flatten(self.b))

    def randomEmptyCoord(self):
        if self.full():
            raise ValueError('No empty spots')
        while True:
            r, c = random.randint(0,2), random.randint(0,2)
            if self.b[r][c] == '':
                return Coord(r,c)

    def set(self, r, c, m):
        if self.b[r][c] != '':
            raise Exception('wat')
        self.b[r][c] = m

    def get(self, r, c):
        return self.b[r][c]

    def draw(self):
        for r in range(3):
            for c in range(3):
                print (self.b[r][c] if self.b[r][c] != '' else ' '),
            print


class Player:
    def __init__(self):
        self.mark = 'W'

    def play(self, board, history):
        pass

class BelowPlayer(Player):
    def __str__(self):
        return 'BelowPlayer'

    # If the position below is available, play there.
    # Otherwise, play a random move.
    def play(self, board, history):
        if len(history) != 0:
            p = history[-1].pos
        else:
            p = board.randomEmptyCoord()

        if board.get((p.r + 2)%3, p.c) == '':
            return Coord((p.r + 2) % 3, p.c)
        else:
            return board.randomEmptyCoord()

class RandomPlayer(Player):
    def __str__(self):
        return 'RandomPlayer'

    def play(self, board, history):
            return board.randomEmptyCoord()

class PureMonteCarloPlayer(Player):
    def __str__(self):
        return 'PureMonteCarloPlayer'

    def play(self, board, history):
        bestSoFar, bestWins = board.randomEmptyCoord(), 0

        for r in range(2):
            for c in range(2):
                if not board.get(r,c):
                    cnt = 0

                    for k in range(100):
                            board_ = copy.deepcopy(board)
                            board_.set(r, c, self.mark)
                            game = Game(RandomPlayer(), RandomPlayer(), startBoard = board_)
                            if game.playGame() == self.mark:
                                cnt += 1

                    if cnt > bestWins:
                        bestSoFar = Coord(r,c)
                        bestWins = cnt

        return bestSoFar


class Game:
    def __init__(self, playerA, playerB, startBoard = None):
        self.history = []

        self.board = startBoard or Board()

        playerA.mark = 'X'
        playerB.mark = 'O'

        self.players = [playerA, playerB]

    def playGame(self):
        t = self.board.count()

        while self.board.winner() == '':
            p = self.players[t%2].play(self.board, self.history)
            self.history.append(Move(p, self.players[t%2].mark))
            self.board.set(p.r, p.c, self.players[t%2].mark)
            t += 1

        return self.board.winner()

# Usa esto como ejemplo para hacer un juego.
game = Game(RandomPlayer(), BelowPlayer())
print game.playGame(), "wins!"
game.board.draw()



N = 20 # how many games to play


playerClasses = [RandomPlayer, BelowPlayer, PureMonteCarloPlayer]

for x in playerClasses:
    for o in playerClasses:
        # Start with a fresh instance every time.
        X = x()
        O = o()
        x_wins = 0
        o_wins = 0
        ties = 0
        record = ""

        for k in range(N):
            # aquí simula un juego entre los dos.
            game = Game(X, O)
            winner = game.playGame()
            record += winner
            if winner == "X":
                x_wins += 1
            else:
                if winner == "O":
                    o_wins += 1
                else:
                    ties += 1
            
        print str(X) +  " vs " + str(O) +  " : "  + str(x_wins) + " - " +  str(o_wins) + " - " + str(ties)
        print record
        print
# Out:
# T wins!
# O X X
# X O O
# X O X
# RandomPlayer vs RandomPlayer : 16 - 3 - 1
# TXXXXOXXXXXXXXOXXOXX
#
# RandomPlayer vs BelowPlayer : 12 - 7 - 1
# XXOTOOXOXXXXOXOXXOXX
#
# RandomPlayer vs PureMonteCarloPlayer : 10 - 10 - 0
# XXOOOOOXXXXXXOXXOOOO
#
# BelowPlayer vs RandomPlayer : 14 - 4 - 2
# XXOOTXXXOXXXTOXXXXXX
#
# BelowPlayer vs BelowPlayer : 9 - 5 - 6
# TXOXXXXXXOTOXOTXTOTT
#
# BelowPlayer vs PureMonteCarloPlayer : 8 - 9 - 3
# OOTXTOOOTXOOXXXXOXOX
#
# PureMonteCarloPlayer vs RandomPlayer : 17 - 2 - 1
# XXOXXXXXTXXXXXXXXXXO
#
# PureMonteCarloPlayer vs BelowPlayer : 13 - 4 - 3
# XXTXOXTXXXXTXXXXOOXO
#
# PureMonteCarloPlayer vs PureMonteCarloPlayer : 12 - 6 - 2
# XXXXXXOXXOTXOOTOXXOX
